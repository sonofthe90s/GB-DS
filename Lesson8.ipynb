# %% [markdown]
# **Задание 1.
# Расскажите, как работает регуляризация в решающих деревьях, какие параметры мы штрафуем в данных алгоритмах?**

# %% [markdown]
# Регуляризация используется для снижения переобучения модели, она позволяет контролировать рост модели,
# опираясь на анализ ее сложности.
# Регуляризация помогает решить проблему переобученности модели.
# Переобучение в большинстве случаев проявляется в том, что в получающихся многочленах слишком большие коэффициенты.
# Соответственно, слишком большие коэффициенты должны штрафоваться.

# %% [markdown]
# **Задание 2.
# По какому принципу рассчитывается "важность признака (feature_importance)" в ансамблях деревьев?**

# %% [markdown]
# На каждом шаге построения дерева выбирается признак и его значение, которые дают наилучшее разбиение данных.
# В зависимости от алгоритма, применяются разные способы подсчета прироста информации,
# чтобы вычислить наилучшее разбиение(например считают критерий Джини или энтропию в каждой части разбиения).
# Важность признака в дереве определяется степенью снижения меры неопределенности,
# т.е. как раз критерия Джини или энтропии и других. Чем выше признак в дереве, тем он важнее.
# В ансамблях деревьев важность признака считается как среднее арифметическое по всем важностям данного признака
# для каждого дерева. В случае, если признак не присутствует в дереве, его важность считается нулевой.
